# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.figure import Figure

# %%
df=pd.read_csv("/Users/mehmetdurgut/Desktop/Computer Science/Data Science/Projects/1)UÜAI Course/Second Week/company_sales_data.csv")

# %%
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
df.describe()
# Out:
#        month_number    facecream     facewash   toothpaste   bathingsoap  \
# count     12.000000    12.000000    12.000000    12.000000     12.000000
# mean       6.500000  2873.333333  1542.916667  5825.833333   9500.833333
# std        3.605551   584.595172   316.733745  1242.032486   2348.095779
# min        1.000000  1990.000000  1120.000000  4550.000000   6100.000000
# 25%        3.750000  2460.000000  1305.000000  4862.500000   8015.000000
# 50%        6.500000  2830.000000  1527.500000  5530.000000   9090.000000
# 75%        9.250000  3435.000000  1765.000000  6400.000000  10045.000000
# max       12.000000  3700.000000  2100.000000  8300.000000  14400.000000
#
#            shampoo  moisturizer  total_units   total_profit
# count    12.000000    12.000000     12.00000      12.000000
# mean   2117.500000  1542.916667  26027.50000  260275.000000
# std     617.724931   316.733745   7014.36594   70143.659404
# min    1200.000000  1120.000000  18330.00000  183300.000000
# ...

# %%
fig1=plt.figure(figsize=(5,4))
ax1=fig1.add_axes([1,1,1,1])

plt.title("company profit for month")
plt.xlabel("month number")
plt.ylabel("total profit")

ax1.set_ylim(100000,500000)
ax1.set_xlim(0.5,12.5)

x=df["month_number"]
y0=df["total_profit"]

ax1.plot(x,y0)

plt.show()

# %%
import matplotlib.colors as mcolors

y1=df["facecream"]
y2=df["facewash"]
y3=df["toothpaste"]
y4=df["bathingsoap"]
y5=df["shampoo"]
y6=df["moisturizer"]

fig2=plt.figure(figsize=(5,4))
ax2=fig2.add_axes([1,1,1,1])


plt.title("sales data")
plt.xlabel("Month number")
plt.ylabel("sales units in number")

ax2.set_xlim(0.5,12.5)
ax2.set_ylim(800,18000)

ax2.plot(x,y1,'-o',color='blue',linewidth=3)
ax2.plot(x,y2,'-o',color='orange',linewidth=3)
ax2.plot(x,y3,'-o',color='green',linewidth=3)
ax2.plot(x,y4,'-o',color='red',linewidth=3)
ax2.plot(x,y5,'-o',color='purple',linewidth=3)
ax2.plot(x,y6,'-o',color='brown',linewidth=3)

plt.show()

# %%
fig3=plt.figure(figsize=(5,4))
ax3=fig3.add_axes([1,1,1,1])
plt.title("Tooth paste Sales data")
plt.xlabel("Month number")
plt.ylabel("Number of units Sold")

ax3.plot(x,y3,'o')
plt.grid(linestyle='--')
plt.legend(['Tooth paste Sales data'],loc=2)
plt.show()

# %%
fig4=plt.figure(figsize=(5,4))
ax4=fig4.add_axes([1,1,1,1])

plt.title("Facewash and facecream sales data")
plt.xlabel("Month Number")
plt.ylabel("Sales units in number")


width = 0.35

ax4.bar(x-width/2,y1,width,align='center',label='Face Cream sales data')#you can add color='blue' parameter
ax4.bar(x+width/2,y2,width,color='orange',align='center',label='Face Wash sales data')
#matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)etc:xerr,yerr[source]

plt.grid(linestyle='--')
plt.legend(loc=2)
#plt.legend(['Face Wash sales data','Face Wash sales data'], loc=2)
plt.show()

# %%
fig5=plt.figure(figsize=(5,4))
ax5=fig5.add_axes([1,1,1,1])
plt.title("Sales data")

pie=[]

products=["FaceCream","FaceWash","Toothpaste","Bathingsoap","Shampoo","Moisturizer"]

pie.append(y1.sum())
pie.append(y2.sum())
pie.append(y3.sum())
pie.append(y4.sum())
pie.append(y5.sum())
pie.append(y6.sum())

ax5.pie(pie,labels=products,autopct='%1.2f%%')
plt.legend(["FaceCream","FaceWash","Toothpaste","Bathingsoap","Shampoo","Moisturizer"],loc=4)

plt.show()

# %%
fig6=plt.figure(figsize=(5,4))
ax6=fig6.add_axes([1,1,1,1])

plt.title("All product sales data using stack plot")
plt.xlabel("Month number")
plt.ylabel("Sales units in Number")

#ax1.fill_between(x, y_stack[1,:], y_stack[2,:], facecolor="#6E5160")

ax6.stackplot(x,y1,y2,y3,y4,y5,y6)

ax6.legend(['FaceCream','FaceWash','Toothpaste','Bathingsoap','Shampoo','Moisturizer'],loc=2)

plt.show()

# %% [markdown]
# # this document is studied at 24.03.23
